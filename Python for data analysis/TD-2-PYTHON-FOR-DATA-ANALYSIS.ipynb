# %%
url = "https://www.afm-telethon.fr/telethon/bref/parrains-resultats-telethon-1379"

# %%
# !pip install requests

# %%
import requests

# %%
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
html = response.content

# %%
response.status_code
# Out:
# 200

# %%
html
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"\n"http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">\n<!--[if IE]>\n<html xmlns="http://www.w3.org/1999/xhtml" class="ie" xml:lang="fr" version="XHTML+RDFa 1.0" dir="ltr"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#">\n<![endif]-->\n<html xmlns="http://www.w3.org/1999/xhtml"\n      xml:lang="fr" version="XHTML+RDFa 1.0"\n      dir="ltr" \n  xmlns:og="http://ogp.me/ns#"\n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  x
# ...

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"
# "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
#
# <!--[if IE]>
# <html xmlns="http://www.w3.org/1999/xhtml" class="ie" xml:lang="fr" version="XHTML+RDFa 1.0" dir="ltr"
#   xmlns:og="http://ogp.me/ns#"
#   xmlns:content="http://purl.org/rss/1.0/modules/content/"
#   xmlns:dc="http://purl.org/dc/terms/"
#   xmlns:foaf="http://xmlns.com/foaf/0.1/"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:sioc="http://rdfs.org/sioc/ns#"
#   xmlns:sioct="http://rdfs.org/sioc/types#"
#   xmlns:skos="http://www.w3.org/2004/02/skos/core#"
#   xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
# <![endif]-->
# ...

# %% [markdown]
# # Use CSS selector to find an element

# %%
element = soup.select('td')

# %%
soup.select("div.field-items table tr td")
# Out:
# [<td class=" txt-petit">Année</td>,
#  <td class=" txt-petit">Parrain</td>,
#  <td class=" txt-petit">
#  <p>Montant collecté</p>
#  </td>,
#  <td class="fdLigneTableau">1987</td>,
#  <td class="fdLigneTableau">Jerry LEWIS</td>,
#  <td class="fdLigneTableau">29 650 000 €</td>,
#  <td>1988</td>,
#  <td>Mireille MATHIEU</td>,
#  <td>28 490 000 €</td>,
#  <td class="fdLigneTableau">1989</td>,
#  <td class="fdLigneTableau">Alain DELON</td>,
#  <td class="fdLigneTableau">40 930 000 €</td>,
#  <td>1990</td>,
#  <td>Claudia CARDINALE</td>,
#  <td>46 510 000 €</td>,
#  <td class="fdLigneTableau">1991</td>,
#  <td class="fdLigneTableau">Jerry LEWIS, Mireille MATHIEU et Ornella MUTTI</td>,
#  <td class="fdLigneTableau">38 650 000 €</td>,
#  <td>1992</td>,
#  <td>Barbara HENDRICKS</td>,
#  <td>47 870 000 €</td>,
#  <td class=" fdLigneTableau">1993</td>,
#  <td class=" fdLigneTableau">Michel SARDOU</td>,
#  <td class=" fdLigneTableau">55 600 000 €</td>,
#  <td>1994</td>,
# ...

# %%
type(element)
# Out:
# list

# %%
texte_data = [elements.get_text() for elements in element]

# %%
texte_data
# Out:
# ['Année',
#  'Parrain',
#  '\nMontant collecté\n',
#  '1987',
#  'Jerry LEWIS',
#  '29 650 000 €',
#  '1988',
#  'Mireille MATHIEU',
#  '28 490 000 €',
#  '1989',
#  'Alain DELON',
#  '40 930 000 €',
#  '1990',
#  'Claudia CARDINALE',
#  '46 510 000 €',
#  '1991',
#  'Jerry LEWIS, Mireille MATHIEU et Ornella MUTTI',
#  '38 650 000 €',
#  '1992',
#  'Barbara HENDRICKS',
#  '47 870 000 €',
#  '1993',
#  'Michel SARDOU',
#  '55 600 000 €',
#  '1994',
#  'Pierre PERRET',
#  '57 520 000 €',
#  '1995',
#  'Serge LAMA',
#  '56 763 000 €',
#  '1996',
#  'Thierry LHERMITTE',
#  '56 872 000 €',
#  '1997',
#  'Robert HOSSEIN',
#  '63 043 286 €',
#  '1998',
#  'Michel BOUJENAH\xa0',
#  '70 449 000 €\xa0',
#  '1999',
#  'Pierre PERRET\xa0',
#  '71 417 798 €\xa0',
#  '2000',
#  'Patrick SEBASTIEN\xa0',
#  '79 640 119 €\xa0',
#  '2001',
#  'Jane BIRKIN\xa0',
#  '81 188 013 €\xa0',
#  '2002',
#  'Axelle RED\xa0',
#  '91 546 548 €\xa0',
#  '2003',
#  'Sandrine KIBERLAIN',
#  '97 657 833 €\xa0',
# ...

# %%
annee, parrain, montant = texte_data[3::3], texte_data[4::3], texte_data[5::3]

# %%
montant
# Out:
# ['29 650 000 €',
#  '28 490 000 €',
#  '40 930 000 €',
#  '46 510 000 €',
#  '38 650 000 €',
#  '47 870 000 €',
#  '55 600 000 €',
#  '57 520 000 €',
#  '56 763 000 €',
#  '56 872 000 €',
#  '63 043 286 €',
#  '70 449 000 €\xa0',
#  '71 417 798 €\xa0',
#  '79 640 119 €\xa0',
#  '81 188 013 €\xa0',
#  '91 546 548 €\xa0',
#  '97 657 833 €\xa0',
#  '104 678 697 €\xa0',
#  '104 078 464 €\xa0',
#  '106 696 532 €\xa0',
#  '102 315 233 €\xa0',
#  '104 911 383 €\xa0',
#  '95 200 117 €\xa0',
#  '90 450 486 €\xa0',
#  '94 091 902 €\xa0',
#  '88 156 400 €\xa0',
#  '89 327 268\xa0€',
#  '92 920 108 €\xa0',
#  '93 850 778 €',
#  '92 740 769 €',
#  '89 189 384 €',
#  '85 844 117 €',
#  '87 026 262 €']

# %%
import pandas as pd

# %%
df = pd.DataFrame({"year" : annee, "parrain" : parrain, "montant" : montant})
df
# Out:
#     year                                         parrain         montant
# 0   1987                                     Jerry LEWIS    29 650 000 €
# 1   1988                                Mireille MATHIEU    28 490 000 €
# 2   1989                                     Alain DELON    40 930 000 €
# 3   1990                               Claudia CARDINALE    46 510 000 €
# 4   1991  Jerry LEWIS, Mireille MATHIEU et Ornella MUTTI    38 650 000 €
# 5   1992                               Barbara HENDRICKS    47 870 000 €
# 6   1993                                   Michel SARDOU    55 600 000 €
# 7   1994                                   Pierre PERRET    57 520 000 €
# 8   1995                                      Serge LAMA    56 763 000 €
# 9   1996                               Thierry LHERMITTE    56 872 000 €
# 10  1997                                  Robert HOSSEIN    63 043 286 €
# 11  1998                                Michel BOUJENAH    70 449 000 €
# ...

# %%
data.csv("sortie.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b034083373a9> in <module>
# ----> 1 data.csv("sortie.csv")
#
# NameError: name 'data' is not defined

# %%
df.montant = df.montant.str.replace(" ", "").str.replace("€", "").astype(int)

# %%
df
# Out:
#     year                                         parrain    montant
# 0   1987                                     Jerry LEWIS   29650000
# 1   1988                                Mireille MATHIEU   28490000
# 2   1989                                     Alain DELON   40930000
# 3   1990                               Claudia CARDINALE   46510000
# 4   1991  Jerry LEWIS, Mireille MATHIEU et Ornella MUTTI   38650000
# 5   1992                               Barbara HENDRICKS   47870000
# 6   1993                                   Michel SARDOU   55600000
# 7   1994                                   Pierre PERRET   57520000
# 8   1995                                      Serge LAMA   56763000
# 9   1996                               Thierry LHERMITTE   56872000
# 10  1997                                  Robert HOSSEIN   63043286
# 11  1998                                Michel BOUJENAH    70449000
# 12  1999                                  Pierre PERRET    71417798
# ...

# %%
df.dtypes
# Out:
# year        int32
# parrain    object
# montant     int32
# dtype: object

# %%
df.year=df.year.astype(int)

# %%
ax = df.plot(kind='bar',x='year', figsize=(15,3))
ax.set_title("Montant collecté depuis 1987 au téléthon")
ax.set_ylabel("Montant collecté")
# Out:
# Text(0, 0.5, 'Montant collecté')

# %%
df.to_csv('Telethon.csv')
